# %% [markdown]
# # California Housing data from 1990 US Census
#
# In this lab we will rely on [Pandas](https://pandas.pydata.org/) and [Seaborn](http://seaborn.pydata.org/) to inspect and visualize data.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import time
import jax.numpy as jnp
import jax

# %% [markdown]
# Load the dataset (if you are using Google Colab, it is already in the `sample_data` folder!).

# %%
data = pd.read_csv('/Users/davide/Desktop/Università/Magistrale - PoliMi/Anno 1 - 2023:2024/Semestre 1/Numerical Analysis/Laboratory/Lab 7/california_housing_train.csv')

# %% [markdown]
# ## Data inspection
#
# Display some basic information.

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    790.000000    282.000000       2.566375
# 50%        434.000000   1167.000000    409.000000       3.544600
# 75%        648.250000   1721.000000    605.250000       4.767000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        17000.000000
# mean        207300.912353
# std         115983.764387
# min          14999.000000
# 25%         119400.000000
# 50%         180400.000000
# 75%         265000.000000
# max         500001.000000

# %% [markdown]
# We are interested in predicting the field `median_house_value`. Plot its distribution.

# %%
sns.distplot(data['median_house_value'])
# Out:
# /var/folders/_v/q6j8tl0d2cb93y5h0_d24pgr0000gn/T/ipykernel_1096/1025832681.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['median_house_value'])
# <Axes: xlabel='median_house_value', ylabel='Density'>

# %% [markdown]
# It looks like the distribution tail has been truncated. Get rid of it to ease the prediction.

# %%
data = data[data['median_house_value'] < 500001]
sns.distplot(data['median_house_value'])
# Out:
# /var/folders/_v/q6j8tl0d2cb93y5h0_d24pgr0000gn/T/ipykernel_1096/332617311.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['median_house_value'])
# <Axes: xlabel='median_house_value', ylabel='Density'>

# %% [markdown]
# Use a scatterplot to visualize the geograhical distribution of the houses.

# %%
sns.scatterplot(data = data, x='longitude' ,y='latitude', hue='median_house_value')
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %% [markdown]
# Look for linear correlations among features.

# %%
data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924703           -0.107711     0.046939
# latitude            -0.924703  1.000000            0.011156    -0.036351
# housing_median_age  -0.107711  0.011156            1.000000    -0.371662
# total_rooms          0.046939 -0.036351           -0.371662     1.000000
# total_bedrooms       0.072053 -0.070561           -0.326365     0.932106
# population           0.103031 -0.116039           -0.294791     0.862707
# households           0.059998 -0.076807           -0.308276     0.921677
# median_income       -0.005244 -0.081594           -0.192482     0.221613
# median_house_value  -0.043938 -0.150570            0.068057     0.141979
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.072053    0.103031    0.059998      -0.005244
# latitude                 -0.070561   -0.116039   -0.076807      -0.081594
# housing_median_age       -0.326365   -0.294791   -0.308276      -0.192482
# total_rooms               0.932106    0.862707    0.921677       0.221613
# total_bedrooms            1.000000    0.882004    0.980512       0.016920
# population                0.882004    1.000000    0.910237       0.036212
# households                0.980512    0.910237    1.000000       0.041296
# median_income             0.016920    0.036212    0.041296       1.000000
# median_house_value        0.073765    0.010418    0.092850       0.645729
#
#                     median_house_value
# longitude                    -0.043938
# latitude                     -0.150570
# housing_median_age            0.068057
# total_rooms                   0.141979
# total_bedrooms                0.073765
# population                    0.010418
# households                    0.092850
# median_income                 0.645729
# median_house_value            1.000000

# %%
sns.heatmap(data.corr(), annot = True, cmap = 'vlag_r', vmin = -1, vmax = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 fig, ax = plt.subplots(figsize=(20, 20))
#       2 sns.heatmap(data.corr(), annot = True, cmap = 'vlag_r', vmin = -1, vmax = 1, ax=ax)
#
# NameError: name 'plt' is not defined

# %%
sns.scatterplot(data = data, x='latitude' ,y='median_house_value') # clearly, is a non-linear correlation
# Out:
# <Axes: xlabel='latitude', ylabel='median_house_value'>

# %% [markdown]
# ## Data normalization
#
# Apply an affine transformation to the data, so that each feature has zero mean and unitary standard deviation.

# %%
data_mean = data.mean()
data_std = data.std()
data_normalized = data.copy(deep=True)

for col in data_normalized.columns:
  data_normalized[col] -= data_mean[col]
  data_normalized[col] /= data_std[col]

# data_normalized = (data - data_mean) / data_std --> pandas magic

data_normalized.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  1.618600e+04  1.618600e+04        1.618600e+04  1.618600e+04
# mean  -1.179994e-15  3.090461e-15       -1.123804e-16  5.267832e-17
# std    1.000000e+00  1.000000e+00        1.000000e+00  1.000000e+00
# min   -2.388896e+00 -1.442990e+00       -2.185414e+00 -1.203912e+00
# 25%   -1.093701e+00 -7.969492e-01       -8.259370e-01 -5.390130e-01
# 50%    5.302748e-01 -6.435726e-01       -2.624469e-02 -2.365777e-01
# 75%    7.793508e-01  9.692058e-01        6.934784e-01  2.266981e-01
# max    2.612550e+00  2.930567e+00        1.893017e+00  1.617924e+01
#
#        total_bedrooms    population    households  median_income  \
# count    1.618600e+04  1.618600e+04  1.618600e+04   1.618600e+04
# mean    -2.107133e-17 -9.130909e-17  6.321398e-17   2.107133e-16
# std      1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
# min     -1.272901e+00 -1.243893e+00 -1.296064e+00  -2.020127e+00
# 25%     -5.748194e-01 -5.575548e-01 -5.696695e-01  -7.350072e-01
# 50%     -2.517208e-01 -2.293624e-01 -2.413704e-01  -1.428298e-01
# 75%      2.571007e-01  2.565694e-01  2.678810e-01   5.803348e-01
# max      1.392217e+01  2.951009e+01  1.442093e+01   7.176532e+00
#
#        median_house_value
# count        1.618600e+04
# mean        -7.726154e-17
# std          1.000000e+00
# min         -1.812127e+00
# 25%         -7.763645e-01
# 50%         -1.896082e-01
# 75%          5.685831e-01
# max          3.137045e+00

# %%
_, ax = plt.subplots(figsize=(16,6))
sns.violinplot(data = data_normalized, ax = ax)
# Out:
# <Axes: >

# %% [markdown]
# ## Train-validation split
#
# Shuffle the data (**hint:** use the [np.random.shuffle](https://numpy.org/doc/stable/reference/random/generated/numpy.random.shuffle.html) function) and split the data as follows:
# - put 80% in the train dataset
# - put 20% in the validation dataset

# %%
np.random.seed(0) # for reproducibility
data_normalized_np = data_normalized.to_numpy()
np.random.shuffle(data_normalized_np)

k = int(data_normalized_np.shape[0] * 0.8)

x_train, y_train, x_test , y_test = data_normalized_np[:k,:-1], data_normalized_np[:k,-1], data_normalized_np[k:,:-1], data_normalized_np[k:, -1]
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((12948, 8), (12948,), (3238, 8), (3238,))

# %% [markdown]
# ## ANN setup
#
# Write a function `initialize_params` that, given the input `layers_size = [n1, n2, ..., nL]`, generates the parameters associated with an ANN, having as many layers as the number of elements of `layers_size`, with as many neurons as `n1`, `n2`, etc.
#
# To initialize the parameters, employ the following strategy:
# - Inizialize the biases with zero value.
# - Inizialize the weights sampling from a Gaussian distribution with zero mean and with standard deviation
# $$
# \sqrt{\frac{2}{n + m}}
# $$
# where $n$ and $m$ are the number of input and output neurons of the corresponding weights matrix (this is known as "Glorot Normal" or "Xavier Normal", see [Glorot, Bengio 2010](http://proceedings.mlr.press/v9/glorot10a/glorot10a.pdf)).
#
# Other popular initializations strategies are:
# - Gaussian distribution with zero mean and with standard deviation (for some constant $K$)
# $$
# \frac{K}{\sqrt{n}}
# $$
# - Uniform distribution
# $$
# \left[-\sqrt{\frac{1}{n}}, \sqrt{\frac{1}{n}}\right]
# $$
# - Uniform distribution (this is known as "Glorot Uniform" or "Xavier Uniform")
# $$
# \left[-\sqrt{\frac{6}{n + m}}, \sqrt{\frac{6}{n + m}}\right]
# $$

# %%
def initialize_params(layers_size):
  np.random.seed(0) # for reproducibility
  params = list()
  for i in range(len(layers_size) - 1):
    n, m = layers_size[i + 1], layers_size[i]
    params.append(np.random.normal(0, np.sqrt(2 / (n + m)), (n, m)))
    params.append(np.zeros((n, 1)))
  return params

# %% [markdown]
# Implement a generic feedforward ANN with a function `y = ANN(x, params)`, using $\tanh$ as activation function.
#
# By convention, both the input and the output have:
# - 1 sample per row
# - 1 feature per column

# %%
def ANN(x, params):
    temp = x.T
    for i in range(0, len(params), 2):
      if i == len(params) - 2:
        temp = params[i] @ temp + params[i + 1]
      else:
        temp = jnp.tanh(params[i] @ temp + params[i + 1])
    return temp.T

# %% [markdown]
# Implement the quadratic (MSE) loss function `L = loss(x, y, params)`, defined as:
#
# $$
# \mathcal{L}(\mathbf{x}, \mathbf{y}, \boldsymbol{\theta}) = \frac{1}{m} \sum_{i=1}^m (y_i - \mathrm{ANN}(x_i, \boldsymbol{\theta}))^2
# $$
#
# where $m$ is the number of samples in $\mathbf{x}$, $\mathbf{y}$ and $\boldsymbol{\theta}$ are the ANN parameters.

# %%
def loss(x, y, params):
  pred = ANN(x, params)
  err = y - pred[:, 0]
  mse = jnp.mean(err ** 2)

  # regularization
  '''
  reg_loss = 0
  for mat in params:
    reg_loss += jnp.linalg.norm(mat) / (mat.shape[0] + mat.shape[1])
  mse += reg_loss
  '''

  return mse

# %% [markdown]
# Test your code, by generating the parameters associated with an ANN with two hidden layers with 5 neurons each and by computing the associated loss.

# %% [markdown]
# ## Training
#
# ### Gradient Descent
#
# Implement the GD method:
# $$
# \begin{split}
# & \boldsymbol{\theta}^{(0)} \text{given} \\
# & \text{for } k = 0, 1, \dots , n_{\text{epochs}} - 1\\
# & \qquad \mathbf{g}^{(k)} = \frac{1}{N} \sum_{i=1}^N \nabla_{\boldsymbol{\theta}} \mathcal{L}(x_i, y_i, \boldsymbol{\theta}^{(k)}) \\
# & \qquad \boldsymbol{\theta}^{(k+1)} = \boldsymbol{\theta}^{(k)} - \lambda \mathbf{g}^{(k)}
# \end{split}
# $$
# where $N$ is the number of training samples. At each iteration, append the current cost to the list `history`.
#
# Train an ANN with two hidden layers with 20 neurons each.
# Try to (manually) optimize the training hyperparameters.
#
# During training, store the MSE error obtained on the train and validation sets in two lists, respectively called `history_train` and `history_valid`. Finally, plot the erros trend and diplay the final values of the errors.

# %% [markdown]
# Hints:
# - Use `jax.jit` to speedup the evaluation of the loss and of the gradients.
# - Use `tqdm` to show a nice progress bar:

# %%
from tqdm.notebook import tqdm
history_train = list()
history_test = list()

loss_fast = jax.jit(loss)
loss_grad = jax.jit(jax.grad(loss_fast, argnums=2))

params = initialize_params([x_train.shape[1], 20, 20, 1])

epsilon = 0.001 # not used in this case, no early stopping
lr = 0.1
epochs = 100

for _ in tqdm(range(epochs)):
  grad = loss_grad(x_train, y_train, params)
  for i in range(len(params)):
      params[i] -= lr * grad[i]
  history_train.append(loss(x_train, y_train, params))
  history_test.append(loss(x_test, y_test, params))

  time.sleep(0.02) # only for testing

plt.plot(history_train)
plt.plot(history_test)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)
# (20, 12948) (20, 1)
# (20, 12948) (20, 1)
# (20, 3238) (20, 1)
# (20, 3238) (20, 1)

# %% [markdown]
# ### Stochastic Gradient Descent
#
# Implement the SGD method:
# $$
# \begin{split}
# & \boldsymbol{\theta}^{(0)} \text{given} \\
# & \text{for } k = 0, 1, \dots , n_{\text{epochs}} - 1\\
# & \qquad \mathbf{g}^{(k)} = \frac{1}{|I_k|} \sum_{i \in I_k} \nabla_{\boldsymbol{\theta}} \mathcal{L}(x_i, y_i, \boldsymbol{\theta}^{(k)}) \\
# & \qquad \boldsymbol{\theta}^{(k+1)} = \boldsymbol{\theta}^{(k)} - \lambda_k \mathbf{g}^{(k)}
# \end{split}
# $$
# where $I_k$ is the current minibatch. To select it, use the function [np.random.choice](https://docs.scipy.org/doc//numpy-1.10.4/reference/generated/numpy.random.choice.html) with replacement.
#
# Consider a linear decay of the learning rate:
# $$
# \lambda_k = \max\left(\lambda_{\textnormal{min}}, \lambda_{\textnormal{max}} \left(1 - \frac{k}{K}\right)\right)
# $$
#
# Test different choices of batch size and try to optimize the learning rate decay strategy.

# %%
lr_min = 0.01
lr_max = 0.1
lr = lr_max

epochs = 100
batch_size = 25
epsilon = 0.001

dec_lr = lambda x, i: max(lr_min, lr_max * (1 - i / epochs)) # linear decay

history_train = list()
history_test = list()

loss_fast = jax.jit(loss)
loss_grad = jax.jit(jax.grad(loss_fast, argnums=2))

params = initialize_params([x_train.shape[1], 20, 20, 1])

for i in tqdm(range(epochs)):
  idx = np.random.choice(np.arange(x_train.shape[0]), batch_size, replace=True)
  grad = loss_grad(x_train[idx], y_train[idx], params)

  for j in range(len(params)):
      params[j] -= lr * grad[j]

  # dropout layers
  for layer in [2, 3, 4, 5]:
    if layer % 2 == 0:
      for x in range(len(params[layer])):
        for y in range(len(params[layer][i])):
          if np.random.uniform(0, 1) >= 0.99999:
            params[layer] = params[layer].at[(x, y)].set(0) # special method for assignment --> JAX obj are immutable
    else:
      for x in range(len(params[layer])):
        if np.random.uniform(0, 1) >= 0.99999:
          params[layer] = params[layer].at[x].set(0)

  lr = dec_lr(lr, i)
  history_train.append(loss(x_train, y_train, params))
  history_test.append(loss(x_test, y_test, params))

  # early stopping
  if history_train[-1] < epsilon:
    break

  time.sleep(0.02) # only for testing

plt.plot(history_train)
plt.plot(history_test)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %% [markdown]
# ## Testing
#
# Load the test dataset `sample_data/california_housing_test.csv` and use the trained model to predict the house prices of the dataset.
#
# Compare predicted prices with actual prices by means of a scatterplot.
#
# Finally, compute the RMSE (root mean square error).

# %%
test = pd.read_csv('/Users/davide/Desktop/Università/Magistrale - PoliMi/Anno 1 - 2023:2024/Semestre 1/Numerical Analysis/Laboratory/Lab 7/california_housing_test.csv')
test = test[test["median_house_value"] < 500001] # remove the tail --> the distribution was cut in that position

# %%
test_real = test["median_house_value"].to_numpy()
test_normalized = (test - data_mean) / data_std # normalize

# %%
test_np = test_normalized.to_numpy()
test_x, test_y = test_np[:, :-1], test_np[:, -1]

# %%
pred = ANN(test_x, params)[:, 0]
pred
# Out:
# Array([ 1.5367882 ,  0.21281633,  0.9457553 , ..., -0.0951215 ,
#        -1.1130216 , -0.49956986], dtype=float32)

# %%
pred_real = pred * data_std["median_house_value"] + data_mean["median_house_value"] # denormalize
pred_real
# Out:
# Array([343180.62, 213436.16, 285261.53, ..., 183259.36,  83508.83,
#        143624.88], dtype=float32)

# %%
plt.scatter(pred_real, test_real)
plt.plot([0, 4e5], [0, 4e5], c="r") # identity function

# %%
err = test_real - pred_real
rmse = np.sqrt(np.mean(err ** 2))
print(f"The RMSE of the neural network is {np.round(np.float64(rmse), 2)}")
# Out:
# The RMSE of the neural network is 60731.98

# %%
print(f"The percentage of the error is {np.round(100 * rmse / test_real.mean(), 2)}%")
# Out:
# The percentage of the error is 31.46%
