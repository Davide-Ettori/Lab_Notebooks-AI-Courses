# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Hyperparameters
learning_rate = 0.001
num_epochs = 10
batch_size = 64

# Data loading
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

# Convolutional Neural Network Model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=20, kernel_size=4, stride=1)
        self.conv2 = nn.Conv2d(in_channels=20, out_channels=20, kernel_size=4, stride=2)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.fc1 = nn.Linear(20 * 5 * 5, 250)
        self.fc2 = nn.Linear(250, 10)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = self.pool(x)
        x = x.view(x.size(0), -1)
        x = self.relu(self.fc1(x))
        x = self.fc2(x)
        return x

model = CNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# Training Loop
for epoch in range(num_epochs):
    total_loss = 0
    correct = 0
    total = 0
    for images, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    avg_loss = total_loss / len(train_loader)
    accuracy = 100 * correct / total
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {avg_loss:.4f}, Accuracy: {accuracy:.2f}%')
# Out:
# Epoch [1/10], Loss: 0.1807, Accuracy: 94.58%
# Epoch [2/10], Loss: 0.0546, Accuracy: 98.29%
# Epoch [3/10], Loss: 0.0373, Accuracy: 98.90%
# Epoch [4/10], Loss: 0.0284, Accuracy: 99.12%
# Epoch [5/10], Loss: 0.0231, Accuracy: 99.25%
# Epoch [6/10], Loss: 0.0180, Accuracy: 99.42%
# Epoch [7/10], Loss: 0.0146, Accuracy: 99.54%
# Epoch [8/10], Loss: 0.0119, Accuracy: 99.61%
# Epoch [9/10], Loss: 0.0101, Accuracy: 99.67%
# Epoch [10/10], Loss: 0.0093, Accuracy: 99.68%

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Hyperparameters
learning_rate = 0.001
num_epochs = 10
batch_size = 64
weight_decay = 1e-4
dropout_prob = 0.5

# Data loading
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

# Convolutional Neural Network Model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=20, kernel_size=4, stride=1)
        self.conv2 = nn.Conv2d(in_channels=20, out_channels=20, kernel_size=4, stride=2)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc1 = nn.Linear(20 * 5 * 5, 250)
        self.fc2 = nn.Linear(250, 10)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = self.pool(x)
        x = x.view(x.size(0), -1)
        x = self.dropout(self.relu(self.fc1(self.dropout(x))))
        x = self.fc2(x)
        return x

model = CNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# Training Loop
for epoch in range(num_epochs):
    total_loss = 0
    correct = 0
    total = 0
    for images, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    avg_loss = total_loss / len(train_loader)
    accuracy = 100 * correct / total
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {avg_loss:.4f}, Accuracy: {accuracy:.2f}%')
# Out:
# Epoch [1/10], Loss: 0.3194, Accuracy: 89.95%
# Epoch [2/10], Loss: 0.1416, Accuracy: 95.69%
# Epoch [3/10], Loss: 0.1190, Accuracy: 96.30%
# Epoch [4/10], Loss: 0.1069, Accuracy: 96.75%
# Epoch [5/10], Loss: 0.0970, Accuracy: 97.07%
# Epoch [6/10], Loss: 0.0904, Accuracy: 97.19%
# Epoch [7/10], Loss: 0.0892, Accuracy: 97.27%
# Epoch [8/10], Loss: 0.0864, Accuracy: 97.40%
# Epoch [9/10], Loss: 0.0826, Accuracy: 97.42%
# Epoch [10/10], Loss: 0.0784, Accuracy: 97.55%

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Hyperparameters
learning_rate = 0.01 
num_epochs = 10
batch_size = 64
weight_decay = 1e-4
dropout_prob = 0.5

# Data loading
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)

# Convolutional Neural Network Model with Batch Normalization
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=20, kernel_size=4, stride=1)
        self.bn1 = nn.BatchNorm2d(20)
        self.conv2 = nn.Conv2d(in_channels=20, out_channels=20, kernel_size=4, stride=2)
        self.bn2 = nn.BatchNorm2d(20)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)
        self.dropout = nn.Dropout(dropout_prob)
        self.fc1 = nn.Linear(20 * 5 * 5, 250)
        self.bn3 = nn.BatchNorm1d(250)
        self.fc2 = nn.Linear(250, 10)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.conv1(x))
        x = self.bn1(x)
        x = self.relu(self.conv2(x))
        x = self.bn2(x)
        x = self.pool(x)
        x = x.view(x.size(0), -1)
        x = self.dropout(self.relu(self.fc1(self.dropout(x))))
        x = self.bn3(x)
        x = self.fc2(x)
        return x

model = CNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

# Training Loop
for epoch in range(num_epochs):
    total_loss = 0
    correct = 0
    total = 0
    for images, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    
    avg_loss = total_loss / len(train_loader)
    accuracy = 100 * correct / total
    print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {avg_loss:.4f}, Accuracy: {accuracy:.2f}%')
# Out:
# Epoch [1/10], Loss: 0.2500, Accuracy: 92.11%
# Epoch [2/10], Loss: 0.1554, Accuracy: 95.24%
# Epoch [3/10], Loss: 0.1477, Accuracy: 95.45%
# Epoch [4/10], Loss: 0.1498, Accuracy: 95.29%
# Epoch [5/10], Loss: 0.1373, Accuracy: 95.81%
# Epoch [6/10], Loss: 0.1435, Accuracy: 95.72%
# Epoch [7/10], Loss: 0.1396, Accuracy: 95.70%
# Epoch [8/10], Loss: 0.1410, Accuracy: 95.75%
# Epoch [9/10], Loss: 0.1389, Accuracy: 95.79%
# Epoch [10/10], Loss: 0.1324, Accuracy: 95.86%
